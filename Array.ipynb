# %%
import numpy as np
import array as arr

# %%
l = arr.array(1,1,12,2,3,4,90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 l = arr.array(1,1,12,2,3,4,90)
#
# TypeError: array() takes at most 2 arguments (7 given)
